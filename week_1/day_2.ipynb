# %%
import requests 
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"content-Type": "application/json"}
MODEL = "llama3.2"

# %%
messages = [
    {
        "role": "user", "content": "Describe some of the business Generative AI Application"
    }
]

# %%
payload = {
    "model": MODEL, 
    "messages": messages, 
    "stream": False
}

# %%
response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI applications are revolutionizing various industries by leveraging artificial intelligence (AI) to generate new, original content. Here are some examples of businesses using generative AI:
#
# 1. **Content Creation**: Companies like Medium and Quora use generative AI to create articles, answers, and responses. This allows for faster and more efficient content creation, reducing the need for human writers.
# 2. **Music Generation**: Generative AI is being used in music composition, with companies like Amper Music and AIVA creating original songs and jingles for clients. These tools use machine learning algorithms to generate music based on user input.
# 3. **Image and Video Generation**: Businesses like Deepfake, Facetune, and Prisma use generative AI to create realistic images and videos. These tools can be used for various purposes, including editing photos, creating special effects, or generating realistic avatars.
# 4. **Chatbots and Virtual Assistants**: Generative AI is being used in chatbot development, enabling companies like Facebook and Google to create more conversational and human-like virtual assistants.
# 5. **Text-to-Speech (TTS)**: Companies like Amazon and IBM use generative AI to generate high-quality TTS voices for voice assistants, audiobooks, and other applications.
# 6. **Personalized Product Recommendations**: Generative AI is being used in e-commerce platforms like Amazon and Netflix to create personalized product recommendations based on user behavior and preferences.
# 7. **Social Media Management**: Businesses use generative AI to create social media content, such as tweets, Instagram posts, and Facebook updates, to save time and improve engagement.
# 8. **Language Translation**: Generative AI is being used in language translation tools like Google Translate and Microsoft Translator to generate more accurate and context-specific translations.
# 9. **Design Automation**: Companies use generative AI to automate design tasks, such as logo creation, graphic design, and 3D modeling, to save time and reduce costs.
# 10. **Marketing Automation**: Generative AI is being used in marketing automation platforms like Marketo and HubSpot to generate personalized marketing content, emails, and ads.
#
# Some notable examples of companies using generative AI include:
#
# * **Amper Music**: Creates original music for videos, ads, and other media.
# * **AIVA**: Develops AI-powered music composition tools for film, TV, and advertising.
# * **Prisma**: Uses AI to transform photos into works of art in the style of famous artists.
# * **Deepfake**: Generates realistic images and videos using deep learning algorithms.
# * **Google**: Uses generative AI in its Google Assistant, Google Photos, and other applications.
#
# These are just a few examples of businesses leveraging generative AI to drive innovation, improve efficiency, and enhance customer experiences.

# %%
import ollama

response = ollama.chat(model= MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Here are some examples of businesses that are utilizing Generative AI applications:
#
# 1. **Art and Design**: Companies like Midjourney, Deep Dream Generator, and Artbreeder use Generative AI to create unique and innovative art pieces, such as paintings, sculptures, and digital artwork.
# 2. **Music and Audio**: Music production companies like Amper Music and AIVA (AI Interactive Vocalist) use Generative AI to compose music tracks, generate beats, and even create personalized soundtracks for films and ads.
# 3. **Fashion and Beauty**: Brands like Estee Lauder and L'Oréal are using Generative AI to design new product packaging, logo designs, and even creating custom makeup looks for their clients.
# 4. **Marketing and Advertising**: Companies like WordLift and Adalo use Generative AI to create personalized ads, generate social media content, and even optimize ad copy for better performance.
# 5. **Healthcare and Medical Imaging**: Hospitals and medical imaging companies like Radiology Network use Generative AI to analyze medical images, detect diseases, and develop personalized treatment plans.
# 6. **Finance and Trading**: Fintech companies like QuantConnect and Alpaca use Generative AI to analyze market trends, predict stock prices, and optimize investment strategies.
# 7. **Education and Learning**: Companies like DreamBox Learn and Curriculum Associates use Generative AI to create personalized learning plans, generate educational content, and even develop adaptive assessments for students.
# 8. **Language Translation**: Companies like Google Translate and Microsoft Translator use Generative AI to improve language translation accuracy, generate text summaries, and even create machine translations.
# 9. **Customer Service**: Chatbot companies like Dialogflow and ManyChat use Generative AI to power conversational interfaces, generate customer support responses, and even provide personalized customer service experiences.
# 10. **Creative Writing**: Companies like AI Writer and Content Blossom use Generative AI to assist writers with content creation, generate articles, and even develop personalized writing styles for clients.
#
# These are just a few examples of the many businesses that are leveraging Generative AI applications to drive innovation, improve efficiency, and create new revenue streams.

# %% [markdown]
# # Exercise

# %%
# A class to represent a Webpage
# If you're not familiar with Classes, check out the "Intermediate Python" notebook

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
ha = Website("https://hassan883.github.io/")

print(ha.title)
print(ha.text)
# Out:
# Hassan-Javed
# Home
# About
# Portfolio
# Service
# Blog
# Contact
# Home
# About
# Service
# Portfolio
# Blog
# Contact
# Hassan
# Javed
# AI Developer based In Pakistan (NASTP @ PAF)
# Get Connected
# Deeper Skillset
# Kobita tumi sopno charini hodsye ersest labo met, consectetur addsipi ctetur adipisicing eod tempor
# Creative Work
# Kobita tumi sopno charini hodsye ersest labo met, consectetur addsipi ctetur adipisicing eod tempor
# Strong Dedication
# Kobita tumi sopno charini hodsye ersest labo met, consectetur addsipi ctetur adipisicing eod tempor
# About Me
# A Passionate AI Developer
# 3+
# Successful
# Years
# About Me
# As an AI Developer with over 3 years of specialized experience in Machine Learning, Deep Learning, Prompt Engineering, and NLP, complemented by a robust 5 years background in Python programming, I am adept at developing sophisticated algorithms and AI-driven solutions that propel organizational success. My expertise extends to cross-functional collaboration and research, where I utilize innovative problem-solving skills to address complex challenges and drive technological advancements. I am passionate about applying my technical and strategic insight to deliver impactful results in dynamic, forward-thinking environments.
# Industrial Exhibition (MUST):
# We presented our Final Year Project and was awarded a participation shield
# Name
# Hassan Javed
# Email
# hassanjaved917127@gmail.com
# Phone
# +92344 3754942
# Address
# Street # 4, near Mehria general store Shah Jeewan colony Chahk Jalal-u-din Girja road Rawalpindi
# Degree
# MS (Data Science)
# Freelance
# Available
# Download CV
# 0
# +
# Years of Experience in AI
# 0
# +
# Years of Experience in Python
# +
# Direct Clients
# 0
# +
# Total Projects
# Skills
# I Work Hard to Improve My Skills Regularly
# >>
# Languages:
# Python
# ,
# JavaScript
# ,
# C
# ,
# C++
# ,
# HTML
# ,
# CSS
# ,
# PHP
# >>
# Data Science:
# Machine Learning
# ,
# Deep Learning
# ,
# LLMs
# ,
# Time Series Classification | Forecasting
# ,
# Computer Vision
# ,
# Data Analysis
# ,
# Data visualization
# ,
# Statistics
# >>
# Tools:
# Jupyter Notebook
# ,
# VS Code
# ,
# Apache Spark
# ,
# Docker
# ,
# Openai API
# >>
# Framework:
# Tensorflow
# ,
# Pytorch
# ,
# Keras
# ,
# Hugging-Face
# ,
# Ollama
# ,
# Flask
# ,
# Django
# ,
# StreamLit
# ,
# ReactJs
# ,
# NodeJs
# ,
# Moongose and ExpressJs
# >>
# Libraries:
# Numpy
# ,
# Pandas
# ,
# Scikit-Learn
# ,
# Scipy
# ,
# Nltk
# ,
# Darts
# ,
# SKtime
# ,
# Matplotlib
# ,
# Seaborn
# ,
# Open CV
# ,
# Chai and Express
# >>
# AWS:
# S3
# ,
# Lambda Function
# ,
# Sage Maker
# ,
# AWS Wrangler
# Services
# What I Do for My Clients
# AI & Machine Learning Development
# I design and implement advanced AI models, with expertise in Llama models, including Llama 3.2 and 3.1 (3B and 8B instruct models) as well as Llama 3.2 (11B and 90B models) for visual tasks. My skill set spans NLP, computer vision, and time series analysis, delivering tailored, high-performance solutions.
# Data Science & Advanced Analytics
# I provide in-depth data analysis and predictive modeling to uncover valuable insights. My work involves data preprocessing, visualization, and advanced analytics, including time series analysis and graph-based techniques, to tackle complex data challenges.
# Machine Learning Engineering & Model Optimization
# I develop, fine-tune, and deploy machine learning models, with strengths in model explainability and performance optimization. My experience includes retrieval-augmented generation (RAG) for enhancing model accuracy and interpretability, as well as using SHAP for model transparency.
# Resume
# I Worked for Some Big Companies
# Experience
# Artificial Intelligence Developer
# (Mar, 2024 - Present)
# NASTP @ PAF (CENTAIC)
# Research and develop chatbots models with Llama3.2 3B Model and multimodel Llama3.2 11B and 90B and applied the RAG and Graph RAG approach. Developed time series classification and forecasting models with LSTM, Sktime, and Aeon, using PyTorch and TensorFlow for synthetic data and model training. Conducted geospatial analysis with QGIS and generated synthetic flight patterns, advancing AI research in aerospace.
# Artificial Intelligence Research Executive
# (Oct, 2023 - Feb, 2024)
# PanaceaLogics
# Experienced in implementing NLP solutions using LLMs, OCR, and advanced models like LayoutLMv2, LiLTv2, and GPT-2. Developed chatbots and PDF extraction systems, leveraging BERT, LangChain, and OpenAI tools. Proficient in Hugging Face and RAG approaches with LLaMA models, alongside optimization techniques such as LORA and QLORA. Skilled in fine-tuning LLMs and mentoring AI and NLP professionals.
# Artificial Intelligence Specialist
# (Mar, 2023 - Oct, 2023)
# PanaceaLogics
# Collected and prepared fish data for classification, segmentation, and object detection, including distance estimation via stereo vision. Calculated fish BMI through image analysis and developed paddle wheel detection for monitoring. Created an NLP system for efficient data retrieval by querying PDF content.
# Data Scientist (Remote)
# (Aug, 2022 - Nov, 2023)
# 2hm Inc
# Researched chicken diseases with data augmentation and classification, and built a performance evaluation app in Flask. Analyzed marketing datasets with data mining, EDA, model building, and reporting. Developed PowerBI dashboards with query triggers to improve data visualization and analysis.
# Software Engineer (Remote)
# (Jan, 2022 - July, 2022)
# 2hm Inc
# Developed full-stack MERN applications, optimized JavaScript solutions, and built backend services with Node.js and Express, testing APIs with Postman. Designed scalable MongoDB databases for high-performance applications.
# Education
# Masters of Science (Data Science)
# (2022 - 2024)
# FAST National University of Computer and Emerging Science
# Utilized Apache Spark for graph data processing and created an Azure ETL pipeline for efficient data processing.
#
# 												Employed Apache Kafka for big data analysis, applying algorithms to reduce computational complexity in large datasets.
#
# 												Enhanced data processing capabilities and improved the efficiency of big data analysis within the project framework.
# Web Programming (TA)
# (Jan, 2023 - Dec, 2023)
# FAST National University of Computer and Emerging Science
# Provided problem-solving support to students, helping them overcome coding challenges and understand complex concepts.
#
# 												Offered technical support including debugging code and resolving various technical issues.
#
# 												Assisted in courses by applying MERN stack concepts (MongoDB, Express.js, React, and Node.js) to enhance learning and practical application.
# Bachelors of Science (Computer Science)
# (2017 - 2021)
# University Of Kotli (AJK)
# Final Year Project in Garbage Detection Using Drone's:
# Developed a custom-trained Mask R-CNN model for detecting garbage in open areas and dustbins, enhancing environmental monitoring.
#
# 												Implemented volume measurement techniques for garbage to optimize waste management processes.
#
# 												Deployed the model using the Django framework and REST APIs, ensuring robust and scalable application deployment.
# Portfolio
# What I Do for My Clients
# All
# Youtube
# Vimeo
# Soundcloud
# Popup
# Content
# Axe Droow
# Youtube
# Mockup Clock
# Vimeo
# Afra Porter
# Soundcloud
# Good Idea
# Popup
# Magic Art
# Popup
# Creative Design
# Content
# We live in a world where we need to move quickly and iterate on our ideas as flexibly as possible.
# Mockups are useful both for the creative phase of the project - for instance when you're trying to figure out your user flows or the proper visual hierarchy - and the production phase when they phase when they will represent the target product. Building mockups strikes the ideal balance ease of modification.
# Client
# Alvaro Morata
# Category
# Content
# Date
# October 07, 2022
# Testimonials
# What Clients Say
# Working with Hassan Javed was a fantastic experience! The QUALITY of his work exceeded expectations with exceptional attention to detail and true professionalism. He was polite, went above and beyond, and delivered everything ON TIME. Highly recommend! 👏
# jamesxiong01
# Netherlands 🇳🇱
# Hassan was very cooperative when it came to revisions and ensuring a high quality of work. Would definitely recommend. Will use again.
# tbr_youtube
# United States 🇺🇸
# Outstanding work on the task! The dedication and meticulous attention to detail were evident from start to finish. I highly recommend him, having collaborated now, and the delivery has been exceptional.
# ritu_singh07
# Malaysia 🇲🇾
# Great experience, very cooperative, flexible and professional. Would highly recommend.
# n_nasr
# United Kingdom 🇬🇧
# Blog
# Latest Blog Posts
# Branding
# August 27, 2022
# When the musics over turn off the light now
# Foliox is a leading web design agency with an award-winning design team that creates innovative, effective websites that capture your brand, improve your conversion rates, and maximize your revenue to help grow your business and achieve your goals.
# In today’s digital world, your website is the first interaction consumers have with your business. That's why almost 95 percent of a user’s first impression relates to web design. It’s also why web design services can have an immense impact on your company’s bottom line.
# That’s why more companies are not only reevaluating their website’s design but also partnering with Foliox, the web design agency that’s driven more than $2.4 billion in revenue for its clients. With over 50 web design awards under our belt, we're confident we can design a custom website that drives sales for your unique business.
# Design
# August 20, 2022
# How good designers can collaborate better
# Foliox is a leading web design agency with an award-winning design team that creates innovative, effective websites that capture your brand, improve your conversion rates, and maximize your revenue to help grow your business and achieve your goals.
# In today’s digital world, your website is the first interaction consumers have with your business. That's why almost 95 percent of a user’s first impression relates to web design. It’s also why web design services can have an immense impact on your company’s bottom line.
# That’s why more companies are not only reevaluating their website’s design but also partnering with Foliox, the web design agency that’s driven more than $2.4 billion in revenue for its clients. With over 50 web design awards under our belt, we're confident we can design a custom website that drives sales for your unique business.
# Cyber
# August 12, 2022
# How to be appreciated for your hard work
# Foliox is a leading web design agency with an award-winning design team that creates innovative, effective websites that capture your brand, improve your conversion rates, and maximize your revenue to help grow your business and achieve your goals.
# In today’s digital world, your website is the first interaction consumers have with your business. That's why almost 95 percent of a user’s first impression relates to web design. It’s also why web design services can have an immense impact on your company’s bottom line.
# That’s why more companies are not only reevaluating their website’s design but also partnering with Foliox, the web design agency that’s driven more than $2.4 billion in revenue for its clients. With over 50 web design awards under our belt, we're confident we can design a custom website that drives sales for your unique business.
# Contact
# I Want to Hear from You
# Address
# Street # 4 Shah Jeewan Colony Girja road Rawalpindi
# Email
# hassanjaved917127@gmail.com
# Phone
# +92344 3754942
# Please Fill Required Fields
# Submit Now
# Portfolio
# Featured Projects
# Featured Project
# Code Enhancer
# A Django web app offering secure user registration, file upload, and integration with OpenAI's API for code enhancements. Users can improve performance, readability, and refactor code.
# Django
# Next.js
# OpenAI API
# Stripe
# Heroku
# Git
# External Link
# GitHub
# AI Developer (Research Officer)
# NASTP (CENTAIC @ PAF)
# © 2024
# To Top

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
# A function that writes a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %% [markdown]
# ```Python
# The API from OpenAI expects to receive messages in a particular structure. Many of the other APIs share this structure:
#
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
messages_for(ha)
# Out:
# [{'role': 'system',
#   'content': 'You are an assistant that analyzes the contents of a website and provides a short summary, ignoring text that might be navigation related. Respond in markdown.'},
#  {'role': 'user',
#   'content': "You are looking at a website titled Hassan-Javed\nThe contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.\n\nHome\nAbout\nPortfolio\nService\nBlog\nContact\nHome\nAbout\nService\nPortfolio\nBlog\nContact\nHassan\nJaved\nAI Developer based In Pakistan (NASTP @ PAF)\nGet Connected\nDeeper Skillset\nKobita tumi sopno charini hodsye ersest labo met, consectetur addsipi ctetur adipisicing eod tempor\nCreative Work\nKobita tumi sopno charini hodsye ersest labo met, consectetur addsipi ctetur adipisicing eod tempor\nStrong Dedication\nKobita tumi sopno charini hodsye ersest labo met, consectetur addsipi ctetur adipisicing eod tempor\nAbout Me\nA Passionate AI Developer\n3+\nSuccessful\nYears\nAbout Me\nAs an AI Developer with over 3 years of specialized experience in Machine Learning, Deep Learning, Prompt Engineering, and NLP, complemented by a robust 5 years background in Python programming, I am adept at developing sophisticated algorithms and AI-driven solutions that propel organizational success. My expertise extends to cross-functional collaboration and research, where I utilize innovative problem-solving skills to address complex challenges and drive technological advancements. I am passionate about applying my technical and strategic insight to deliver impactful results in dynamic, forward-thinking environments.\nIndustrial Exhibition (MUST):\nWe presented our Final Year Project and was awarded a participation shield\nName\nHassan Javed\nEmail\nhassanjaved917127@gmail.com\nPhone\n+92344 3754942\nAddress\nStreet # 4, near Mehria general store Shah Jeewan colony Chahk Jalal-u-din Girja road Rawalpindi\nDegree\nMS (Data Science)\nFreelance\nAvailable\nDownload CV\n0\n+\nYears of Experience in AI\n0\n+\nYears of Experience in Python\n+\nDirect Clients\n0\n+\nTotal Projects\nSkills\nI Work Hard to Improve My Skills Regularly\n>>\nLanguages:\nPython\n,\nJavaScript\n,\nC\n,\nC++\n,\nHTML\n,\nCSS\n,\nPHP\n>>\nData Science:\nMachine Learning\n,\nDeep Learning\n,\nLLMs\n,\nTime Series Classification | Forecasting\n,\nComputer Vision\n,\nData Analysis\n,\nData visualization\n,\nStatistics\n>>\nTools:\nJupyter Notebook\n,\nVS Code\n,\nApache Spark\n,\nDocker\n,\nOpenai API\n>>\nFramework:\nTensorflow\n,\nPytorch\n,\nKeras\n,\nHugging-Face\n,\nOllama\n,\nFlask\n,\nDjango\n,\nStreamLit\n,\nReactJs\n,\nNodeJs\n,\nMoongose and ExpressJs\n>>\nLibraries:\nNumpy\n,\nPandas\n,\nScikit-Learn\n,\nScipy\n,\nNltk\n,\nDarts\n,\nSKtime\n,\nMatplotlib\n,\nSeaborn\n,\nOpen CV\n,\nChai and Express\n>>\nAWS:\nS3\n,\nLambda Function\n,\nSage Maker\n,\nAWS Wrangler\nServices\nWhat I Do for My Clients\nAI & Machine Learning Development\nI design and implement advanced AI models, with expertise in Llama models, including Llama 3.2 and 3.1 (3B and 8B instruct models) as well as Llama 3.2 (11B and 90B models) for visual tasks. My skill set spans NLP, computer vision, and time series analysis, delivering tailored, high-performance solutions.\nData Science & Advanced Analytics\nI provide in-depth data analysis and predictive modeling to uncover valuable insights. My work involves data preprocessing, visualization, and advanced analytics, including time series analysis and graph-based techniques, to tackle complex data challenges.\nMachine Learning Engineering & Model Optimization\nI develop, fine-tune, and deploy machine learning models, with strengths in model explainability and performance optimization. My experience includes retrieval-augmented generation (RAG) for enhancing model accuracy and interpretability, as well as using SHAP for model transparency.\nResume\nI Worked for Some Big Companies\nExperience\nArtificial Intelligence Developer\n(Mar, 2024 - Present)\nNASTP @ PAF (CENTAIC)\nResearch and develop chatbots models with Llama3.2 3B Model and multimodel Llama3.2 11B and 90B and applied the RAG and Graph RAG approach. Developed  ...

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    website = Website(url)
    response = ollama.chat(model= MODEL, messages=messages_for(website))
    return response['message']['content']

# %%
summarize("https://edwarddonner.com")
# Out:
# "# Website Summary\n\n### About the Founder\n\n* Edward Donner is a writer, programmer, and DJ who shares his passion for artificial intelligence (AI) and language models (LLMs).\n* He co-founded Nebula.io, applying AI to help people discover their potential.\n* He has previously founded and CEO'd AI startup untapt, acquired in 2021.\n\n### News and Announcements\n\n* **Mastering AI and LLM Engineering – Resources**: A list of resources for improving AI and LLM skills. (November 13, 2024)\n* **From Software Engineer to AI Data Scientist – resources**: Resources to help software engineers transition into AI data science. (October 16, 2024)\n* **Outsmart LLM Arena – a battle of diplomacy and deviousness**: A new arena where LLMs compete in a battle of diplomacy and deviousness. (June 26, 2024)\n* **Choosing the Right LLM: Toolkit and Resources**: A collection of tools and resources for selecting the right LLM."

# %%
# A function to display this nicely in the Jupyter output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")
# Out:
# **Summary of Website**
# =====================================
#
# ### About the Founder
#
# * Edward Donner is the co-founder and CTO of Nebula.io, a company applying AI to help people discover their potential.
# * He's also the founder and CEO of AI startup untapt, acquired in 2021.
#
# ### Content Summary
# ---------------
#
# * **Recent News**
# 	+ November 13, 2024: Mastering AI and LLM Engineering – Resources ( blog post )
# 	+ October 16, 2024: From Software Engineer to AI Data Scientist – resources ( blog post )
# 	+ August 6, 2024: Outsmart LLM Arena – a battle of diplomacy and deviousness ( announcement )
# 	+ June 26, 2024: Choosing the Right LLM: Toolkit and Resources ( announcement )
# * **Other Content**
# 	+ The website features an "Outsmart" arena where LLMs compete in a game of diplomacy and deception.
# 	+ Edward Donner shares his interests, including DJing, amateur electronic music production, and Hacker News.
